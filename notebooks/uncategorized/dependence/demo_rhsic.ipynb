# %% [markdown]
# # HSIC

# %% [markdown]
# In this notebook, I will be looking at HSIC and replicating some MATLAB code found [here](). There are 3 main functions:
# * HSIC
# * HSIC Derivative
# * Randomized HSIC Derivative

# %%
import sys
sys.path.insert(0, '/home/emmanuel/code/kernellib')
from kernellib.dependence import HSIC, RHSIC
import numpy as np
import numba
from sklearn.gaussian_process.kernels import RBF, WhiteKernel
from sklearn.utils.validation import check_array
from sklearn.preprocessing import KernelCenterer
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.utils import check_random_state

from scipy.spatial.distance import pdist
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Parameters

# %%
np.random.seed(1234)

num_points = 10000

kernel = RBF()

num_rand_features = 50

# %% [markdown]
# ## Toy Data

# %%
# High Correlation, High Dependence
x1 = np.random.rand(num_points, 1)

y1 = x1 + 0.1 * np.random.randn(num_points, 1)

# Low Correlation, High Dependence
t = 2 * np.pi * np.random.rand(num_points, 1)

x2 = np.cos(t) + 0.1 * np.random.randn(num_points, 1)
y2 = np.sin(t) + 0.1 * np.random.randn(num_points, 1)

# Low Correlation, Low Dependence
x3 = np.random.rand(num_points, 1)
y3 = np.random.rand(num_points, 1)

# %%
fig, ax = plt.subplots(figsize=(20,5), nrows=1, ncols=3)

ax[0].scatter(x1, y1)
ax[0].set_title('High Correlation, High Dependence')

ax[1].scatter(x2, y2)
ax[1].set_title('Low Correlation, High Dependence')

ax[2].scatter(x3, y3)
ax[2].set_title('Low Correlation, Low Dependence')

plt.show()

# %% [markdown]
# ## HSIC

# %%
hsic_vals = dict()
sens = dict()

# %%
lhsic_model = HSIC(kernel='lin', random_state=1234)

lhsic_model.fit(x1, y1);

hsic_vals['lhh'] = lhsic_model.hsic_value
sens['lhh'] = lhsic_model.sensitivity()

# hsic value
print(f"HSIC (H,H): {hsic_vals['lhh']}")
# Out:
# No derivatives found. Recalculating derivative.
# HSIC (H,H): 0.007106768638659568

# %%
lhsic_model = HSIC(kernel='lin', random_state=1234)

lhsic_model.fit(x2, y2);

hsic_vals['lhl'] = lhsic_model.hsic_value
sens['lhl'] = lhsic_model.sensitivity()

# hsic value
print(f"HSIC (H,L): {hsic_vals['lhl']}")
# Out:
# No derivatives found. Recalculating derivative.
# HSIC (H,L): 8.625366012798845e-05

# %%
lhsic_model = HSIC(kernel='lin', random_state=1234)

lhsic_model.fit(x3, y3);

hsic_vals['lll'] = lhsic_model.hsic_value
sens['lll'] = lhsic_model.sensitivity()

# hsic value
print(f"HSIC (L,L): {hsic_vals['lll']}")
# Out:
# No derivatives found. Recalculating derivative.
# HSIC (L,L): 7.769637451118842e-07

# %%
fig, ax = plt.subplots(figsize=(20,5), nrows=1, ncols=3)

ax[0].scatter(x1, y1)
ax[0].set_title('High Correlation, High Dependence')

ax[1].scatter(x2, y2)
ax[1].set_title('Low Correlation, High Dependence')

ax[2].scatter(x3, y3)
ax[2].set_title('Low Correlation, Low Dependence')

plt.show()

fig, ax = plt.subplots(figsize=(20,5), nrows=1, ncols=3)

my_colors = [
    '#000000',
    '#ff0000', 
    
]

cmap=LinearSegmentedColormap.from_list('mycmap', my_colors)


ax[0].scatter(x1, y1, c=sens['lhh'], cmap=cmap)
ax[0].set_title(f"High Correlation, High Dependence: {hsic_vals['lhh']:.4f} ")

ax[1].scatter(x2, y2, c=sens['lhl'], cmap=cmap)
ax[1].set_title(f"Low Correlation, High Dependence: {hsic_vals['lhl']:.4f} ")

ax[2].scatter(x3, y3, c=sens['lll'], cmap=cmap)
ax[2].set_title(f"Low Correlation, Low Dependence: {hsic_vals['lll']:.4f} ")

plt.show()

# %% [markdown]
# ## HSIC (RBF Kernel)

# %%
hsic_model = HSIC(kernel='rbf', random_state=1234)

hsic_model.fit(x1, y1);

hsic_vals['hh'] = hsic_model.hsic_value
sens['hh'] = hsic_model.sensitivity()

# hsic value
print(f"HSIC (H,H): {hsic_vals['hh']}")
# Out:
# No derivatives found. Recalculating derivative.
# HSIC (H,H): 0.09821747501788343

# %%
hsic_model = HSIC(kernel='rbf', random_state=1234)

hsic_model.fit(x2, y2);

hsic_vals['lh'] = hsic_model.hsic_value

# hsic value
print(f"HSIC (L,H): {hsic_model.hsic_value}")
      
sens['lh'] = hsic_model.sensitivity()
# Out:
# HSIC (L,H): 0.0164660517971684
# No derivatives found. Recalculating derivative.

# %%
hsic_model = HSIC(kernel='rbf', random_state=1234)

hsic_model.fit(x3, y3);

hsic_vals['ll'] = hsic_model.hsic_value

# hsic value
print(f"HSIC (L,L): {hsic_model.hsic_value}")
      
sens['ll'] = hsic_model.sensitivity()
# Out:
# HSIC (L,L): 2.497939819507499e-05
# No derivatives found. Recalculating derivative.

# %%
# ORIGINAL DATA
fig, ax = plt.subplots(figsize=(20,5), nrows=1, ncols=3)

ax[0].scatter(x1, y1)
ax[0].set_title('High Correlation, High Dependence')

ax[1].scatter(x2, y2)
ax[1].set_title('Low Correlation, High Dependence')

ax[2].scatter(x3, y3)
ax[2].set_title('Low Correlation, Low Dependence')

plt.show()


# LINEAR KERNEL

fig, ax = plt.subplots(figsize=(20,5), nrows=1, ncols=3)

my_colors = [
    '#000000',
    '#ff0000', 
    
]

cmap=LinearSegmentedColormap.from_list('mycmap', my_colors)


ax[0].scatter(x1, y1, c=sens['lhh'], cmap=cmap)
ax[0].set_title(f"High Correlation, High Dependence: {hsic_vals['lhh']:.4f} ")

ax[1].scatter(x2, y2, c=sens['lhl'], cmap=cmap)
ax[1].set_title(f"Low Correlation, High Dependence: {hsic_vals['lhl']:.4f} ")

ax[2].scatter(x3, y3, c=sens['lll'], cmap=cmap)
ax[2].set_title(f"Low Correlation, Low Dependence: {hsic_vals['lll']:.4f} ")

plt.show()

# RBF KERNEL
fig, ax = plt.subplots(figsize=(20,5), nrows=1, ncols=3)

my_colors = [
    '#000000',
    '#ff0000', 
    
]

cmap=LinearSegmentedColormap.from_list('mycmap', my_colors)


ax[0].scatter(x1, y1, c=sens['hh'], cmap=cmap)
ax[0].set_title(f"High Correlation, High Dependence: {hsic_vals['hh']:.4f} ")

ax[1].scatter(x2, y2, c=sens['lh'], cmap=cmap)
ax[1].set_title(f"Low Correlation, High Dependence: {hsic_vals['lh']:.4f} ")

ax[2].scatter(x3, y3, c=sens['ll'], cmap=cmap)
ax[2].set_title(f"Low Correlation, Low Dependence: {hsic_vals['ll']:.4f} ")

plt.show()

# %% [markdown]
# ## Randomized HSIC

# %%
rhsic_model = RHSIC(kernel_approx='rff', n_features=50, random_state=1234)

rhsic_model.fit(x1, y1);

hsic_vals['rhh'] = rhsic_model.hsic_value
derX, derY = rhsic_model.derivative()
sens['rhh'] = rhsic_model.sensitivity()

# hsic value
print(f"RHSIC (H,H): {rhsic_model.hsic_value:.4f}")
# Out:
# RHSIC (H,H): 0.0836

# %%
rhsic_model = RHSIC(kernel_approx='rff', n_features=100, random_state=1234)

rhsic_model.fit(x2, y2);

# hsic_vals['hh']  = 
hsic_vals['rlh'] = rhsic_model.hsic_value
sens['rlh'] = rhsic_model.sensitivity()

# hsic value
print(f"RHSIC (H,H): {rhsic_model.hsic_value:.4f}")
# Out:
# No derivatives found. Recalculating derivative.
# RHSIC (H,H): 0.0130

# %%
rhsic_model = RHSIC(kernel_approx='rff', n_features=50, random_state=1234)

rhsic_model.fit(x3, y3);

# hsic_vals['hh']  = 
hsic_vals['rll'] = rhsic_model.hsic_value
sens['rll'] = rhsic_model.sensitivity()

# hsic value
print(f"RHSIC (H,H): {rhsic_model.hsic_value:.4f}")
# Out:
# No derivatives found. Recalculating derivative.
# RHSIC (H,H): 0.0000

# %%
# ORIGINAL DATA
fig, ax = plt.subplots(figsize=(20,5), nrows=1, ncols=3)

ax[0].scatter(x1, y1)
ax[0].set_title('High Correlation, High Dependence')

ax[1].scatter(x2, y2)
ax[1].set_title('Low Correlation, High Dependence')

ax[2].scatter(x3, y3)
ax[2].set_title('Low Correlation, Low Dependence')

plt.show()

# LINEAR KERNEL

fig, ax = plt.subplots(figsize=(20,5), nrows=1, ncols=3)

my_colors = [
    '#000000',
    '#ff0000', 
    
]

cmap=LinearSegmentedColormap.from_list('mycmap', my_colors)


ax[0].scatter(x1, y1, c=sens['lhh'], cmap=cmap)
ax[0].set_title(f"High Correlation, High Dependence: {hsic_vals['lhh']:.4f} ")

ax[1].scatter(x2, y2, c=sens['lhl'], cmap=cmap)
ax[1].set_title(f"Low Correlation, High Dependence: {hsic_vals['lhl']:.4f} ")

ax[2].scatter(x3, y3, c=sens['lll'], cmap=cmap)
ax[2].set_title(f"Low Correlation, Low Dependence: {hsic_vals['lll']:.4f} ")

plt.show()
                
# RBF KERNEL
fig, ax = plt.subplots(figsize=(20,5), nrows=1, ncols=3)

my_colors = [
    '#000000',
    '#ff0000', 
    
]

cmap=LinearSegmentedColormap.from_list('mycmap', my_colors)


ax[0].scatter(x1, y1, c=sens['hh'], cmap=cmap)
ax[0].set_title(f"HSIC: {hsic_vals['hh']:.4f} ")

ax[1].scatter(x2, y2, c=sens['lh'], cmap=cmap)
ax[1].set_title(f"HSIC: {hsic_vals['lh']:.4f} ")

ax[2].scatter(x3, y3, c=sens['ll'], cmap=cmap)
ax[2].set_title(f"HSIC: {hsic_vals['ll']:.4f} ")

plt.show()

# RFF KERNEL
fig, ax = plt.subplots(figsize=(20,5), nrows=1, ncols=3)

my_colors = [
    '#000000',
    '#ff0000', 
]

cmap=LinearSegmentedColormap.from_list('mycmap', my_colors)


ax[0].scatter(x1, y1, c=sens['rhh'], cmap=cmap)
ax[0].set_title(f"RHSIC: {hsic_vals['rhh']:.4f} ")

ax[1].scatter(x2, y2, c=sens['rlh'], cmap=cmap)
ax[1].set_title(f"RHSIC: {hsic_vals['rlh']:.4f} ")

ax[2].scatter(x3, y3, c=sens['rll'], cmap=cmap)
ax[2].set_title(f"RHSIC: {hsic_vals['rll']:.4f} ")

plt.show()

# %% [markdown]
# ### Timings

# %%
# %timeit lhsic_model.fit(x1, y1)
# %timeit hsic_model.fit(x1, y1)
# %timeit rhsic_model.fit(x1, y1)
# Out:
# 7.03 s ± 66.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 7.23 s ± 351 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 89.2 ms ± 418 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit lhsic_model.sensitivity()
# %timeit hsic_model.sensitivity()
# %timeit rhsic_model.sensitivity()
# Out:
# 229 µs ± 280 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 229 µs ± 232 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 267 µs ± 44.3 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%time

n_samples = 100
temp_x = np.linspace(1, n_samples, n_samples)
temp_y = temp_x.copy()

hsic_model = HSIC(kernel='rbf', random_state=1234)
hsic_model.fit(temp_x[:, None], temp_y[:, None]);
# Out:
# CPU times: user 10.7 ms, sys: 5.1 ms, total: 15.8 ms
# Wall time: 5.61 ms

# %%
print(hsic_model.hsic_value)
print(hsic_model.sigma_x)
print(hsic_model.sigma_y)
# Out:
# 0.12651697709233692
# 21.213203435596427
# 21.213203435596427

# %%
hsic_model.K_y.shape
# Out:
# (100, 100)

# %%
fig, ax = plt.subplots()

p = ax.imshow(hsic_model.K_x, )

plt.show()

# %%
7.0840e+05 / 708402.7777777778
# Out:
# 0.9999960788158024

# %%
n_samples = 1000
temp_x = np.linspace(1, n_samples, n_samples)
temp_y = temp_x.copy()

# %%
# %%time

rhsic_model = RHSIC(kernel='rbf', n_features=100, sigma_x=206.4752, sigma_y=206.4752)
rhsic_model.fit(temp_x[:, None], temp_y[:, None])
# Out:
# CPU times: user 1.17 s, sys: 973 µs, total: 1.17 s
# Wall time: 78.7 ms

# %%
print(rhsic_model.hsic_value)
print(rhsic_model.sigma_x)
print(rhsic_model.sigma_y)
# Out:
# 0.13140151834158692
# 206.4752
# 206.4752

# %%
print(rhsic_model.Wx.shape)
print(rhsic_model.Zx.shape)
print(rhsic_model.Zx_mean.shape)
print(rhsic_model.Zxc.shape)
print(rhsic_model.Rxy.shape)
# Out:
# (1, 100)
# (1000, 100)
# (100,)
# (1000, 100)
# (100, 100)

# %%
fig, ax = plt.subplots()

ax.plot(np.real(rhsic_model.Zx_mean), )

plt.show()
